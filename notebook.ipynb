# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv('/Users/muneebsamad/Desktop/Material/Project-3-team-6/Resources/600K US Housing Properties.csv')
# Out:
# /var/folders/lm/_0dxbsxn12x_gj203f_bq6br0000gn/T/ipykernel_78330/358520619.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/muneebsamad/Desktop/Material/Project-3-team-6/Resources/600K US Housing Properties.csv')

# %%
df
# Out:
#                                              property_url  property_id  \
# 0       https://www.zillow.com/homedetails/3-Plat-83-1...   2064212272
# 1       https://www.zillow.com/homedetails/117-3rd-St-...    249518113
# 2       https://www.zillow.com/homedetails/LOT-2A-Fron...   2077729913
# 3       https://www.zillow.com/homedetails/LOT-A-Plat-...   2067488502
# 4       https://www.zillow.com/homedetails/335-Cassiar...    249518139
# ...                                                   ...          ...
# 599995  https://www.zillow.com/homedetails/6317-Virgin...      4303608
# 599996  https://www.zillow.com/homedetails/LOT-16-Ray-...   2078144422
# 599997  https://www.zillow.com/homedetails/12S135-Lemo...      4604875
# 599998  https://www.zillow.com/homedetails/4701-Abbey-...     65578365
# 599999  https://www.zillow.com/homedetails/321-Allen-A...      4418670
#
#                                        address         street_name apartment  \
# ...

# %%
df_cleaned = df.dropna(subset=['longitude', 'latitude'])

# %%
df_new = df.drop(columns=['property_url', 'agency_name', 'agent_name', 'agent_phone', 'is_owned_by_zillow', 'RunDate', 'total_num_units'])

# %%
df_new.dtypes
# Out:
# property_id          int64
# address             object
# street_name         object
# apartment           object
# city                object
# state               object
# latitude           float64
# longitude          float64
# postcode            object
# price              float64
# bedroom_number     float64
# bathroom_number    float64
# price_per_unit     float64
# living_space       float64
# land_space         float64
# land_space_unit     object
# broker_id          float64
# property_type       object
# property_status     object
# year_build         float64
# listing_age          int64
# dtype: object

# %%
# Out:
#         property_id                                 address  \
# 0        2064212272       3 Plat #83-10, Wrangell, AK 99929
# 1         249518113          117 3rd St, Wrangell, AK 99929
# 2        2077729913     LOT 2A Front St, Wrangell, AK 99929
# 3        2067488502  LOT A Plat #2009-6, Wrangell, AK 99929
# 4         249518139      335 Cassiar St, Wrangell, AK 99929
# ...             ...                                     ...
# 599995      4303608    6317 Virginia Ln, Matteson, IL 60443
# 599996   2078144422  LOT 16 Ray Ave, West Chicago, IL 60185
# 599997      4604875      12S135 Lemont Rd, Lemont, IL 60439
# 599998     65578365       4701 Abbey Ln, Matteson, IL 60443
# 599999      4418670   321 Allen Ave, West Chicago, IL 60185
#
#                street_name apartment          city state   latitude  \
# 0              Plat #83-10       NaN      Wrangell    AK        NaN
# 1                   3rd St       NaN      Wrangell    AK  56.474518
# ...

# %%
df2 = df1[df1['state'] !='TX']

# %%
df3 = df1.drop(columns = ['address'])

# %%
df4.to_csv('UsProperties.csv', index=False)

# %%
df4 = df2.drop(columns=['street_name'])

# %%
df4
# Out:
#         property_id                                 address apartment  \
# 0        2064212272       3 Plat #83-10, Wrangell, AK 99929       NaN
# 1         249518113          117 3rd St, Wrangell, AK 99929       NaN
# 2        2077729913     LOT 2A Front St, Wrangell, AK 99929       NaN
# 3        2067488502  LOT A Plat #2009-6, Wrangell, AK 99929       NaN
# 4         249518139      335 Cassiar St, Wrangell, AK 99929       NaN
# ...             ...                                     ...       ...
# 599995      4303608    6317 Virginia Ln, Matteson, IL 60443       NaN
# 599996   2078144422  LOT 16 Ray Ave, West Chicago, IL 60185       NaN
# 599997      4604875      12S135 Lemont Rd, Lemont, IL 60439       NaN
# 599998     65578365       4701 Abbey Ln, Matteson, IL 60443       NaN
# 599999      4418670   321 Allen Ave, West Chicago, IL 60185       NaN
#
#                 city state   latitude   longitude postcode     price  \
# ...
